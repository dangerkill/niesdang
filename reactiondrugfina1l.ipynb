# %%
import pandas as pd #dataset manipulate
import numpy as np # to provides standard trigonometric functions for arithmetic operations, handling complex numbers
import matplotlib.pyplot as plt #visualize data
import seaborn as sns #for data visualization and exploratory data analysis
from collections import Counter #counting the frequently values
# %matplotlib inline

# %% [markdown]
# #Import datasets

# %% [markdown]
# ##Drug dataset

# %%
#load dataset drug
drug = pd.read_csv('E:/New folder (5)/niesdang/DRUG18Q1.csv',sep = '$')
drug.info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686461 entries, 0 to 1686460
# Data columns (total 20 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   primaryid      1686461 non-null  int64
#  1   caseid         1686461 non-null  int64
#  2   drug_seq       1686461 non-null  int64
#  3   role_cod       1686461 non-null  object
#  4   drugname       1686450 non-null  object
#  5   prod_ai        1657701 non-null  object
#  6   val_vbm        1686461 non-null  int64
#  7   route          1276188 non-null  object
#  8   dose_vbm       1031178 non-null  object
#  9   cum_dose_chr   39722 non-null    float64
#  10  cum_dose_unit  39729 non-null    object
# ...

# %% [markdown]
# ###check 20 first rows

# %%
#show first 20 records

drug.head(20)
# Out:
#     primaryid    caseid  drug_seq role_cod                  drugname  \
# 0   100035813  10003581         1       PS                    JAKAFI
# 1   100035813  10003581         2       SS                    JAKAFI
# 2   100035813  10003581         3       SS                    JAKAFI
# 3   100035813  10003581         4        C               METOPROLOL.
# 4   100035813  10003581         5        C                LORAZEPAM.
# 5   100035813  10003581         6        C                    EXJADE
# 6   100035813  10003581         7        C                   NORVASC
# 7   100035813  10003581         8        C              MIRTAZAPINE.
# 8   100048965  10004896         1       PS                  DILANTIN
# 9   100048965  10004896         2       SS                 ZITHROMAX
# 10  100048965  10004896         3       SS              EPINEPHRINE.
# 11  100048965  10004896         4       SS         MORPHINE SULFATE.
# 12  100048965  10004896         5       SS  APRESOLINE HYDROCHLORIDE
# ...

# %% [markdown]
# ##Reaction dataset & check the information of dataset

# %%
#load dataset reation
reaction= pd.read_csv('E:/New folder (5)/niesdang/REAC18Q1.csv',sep='$')
reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206259 entries, 0 to 1206258
# Data columns (total 4 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   primaryid     1206259 non-null  int64
#  1   caseid        1206259 non-null  int64
#  2   pt            1206259 non-null  object
#  3   drug_rec_act  2844 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 36.8+ MB

# %% [markdown]
# ### remove duplicates

# %%
#remove duplicates values
reaction = reaction.drop_duplicates(subset= 'primaryid')
reaction
# Out:
#          primaryid    caseid                           pt drug_rec_act
# 0        100035813  10003581         Blood count abnormal          NaN
# 2        100048965  10004896        Drug hypersensitivity          NaN
# 3        100054258  10005425      Acute coronary syndrome          NaN
# 7        100058884  10005888  Acute myocardial infarction          NaN
# 27       100060834  10006083          Psychiatric symptom          NaN
# ...            ...       ...                          ...          ...
# 1206248   99965822   9996582          Metastatic neoplasm          NaN
# 1206250   99979614   9997961    Cardio-respiratory arrest          NaN
# 1206254   99991303   9999130                    Pneumonia          NaN
# 1206255  999913117   9999131         Basal cell carcinoma          NaN
# 1206257   99994482   9999448               Prostatomegaly          NaN
#
# [412702 rows x 4 columns]

# %% [markdown]
# ##import demographic dataset & check information

# %%
demographic = pd.read_csv('E:/New folder (5)/niesdang/DEMO18Q1.csv',sep='$')
demographic.info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412702 entries, 0 to 412701
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   primaryid         412702 non-null  int64
#  1   caseid            412702 non-null  int64
#  2   caseversion       412702 non-null  int64
#  3   i_f_code          412702 non-null  object
#  4   event_dt          211550 non-null  float64
#  5   mfr_dt            391711 non-null  float64
#  6   init_fda_dt       412702 non-null  int64
#  7   fda_dt            412702 non-null  int64
#  8   rept_cod          412702 non-null  object
#  9   auth_num          14188 non-null   object
#  10  mfr_num           391713 non-null  object
# ...

# %% [markdown]
# ##check dataset head &remove duplicate

# %%
demographic.head(20)
# Out:
#      primaryid    caseid  caseversion i_f_code    event_dt      mfr_dt  \
# 0    100035813  10003581            3        F  20140110.0  20180116.0
# 1    100048965  10004896            5        F         NaN  20180201.0
# 2    100054258  10005425            8        F  20130701.0  20180105.0
# 3    100058884  10005888            4        F      2011.0  20180302.0
# 4    100060834  10006083            4        F      2014.0  20171204.0
# 5    100065478  10006547            8        F  20120329.0  20180130.0
# 6    100066292  10006629            2        F         NaN  20180219.0
# 7    100071964  10007196            4        F  20130614.0  20180305.0
# 8    100100246  10010024            6        F    200805.0  20180312.0
# 9    100113852  10011385            2        F    201310.0  20180109.0
# 10  1001163916  10011639           16        F      2015.0  20180312.0
# 11   100117582  10011758            2        F  20140302.0  20151118.0
# ...

# %%
demographic = demographic.drop_duplicates(subset= 'primaryid')
demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412702 entries, 0 to 412701
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   primaryid         412702 non-null  int64
#  1   caseid            412702 non-null  int64
#  2   caseversion       412702 non-null  int64
#  3   i_f_code          412702 non-null  object
#  4   event_dt          211550 non-null  float64
#  5   mfr_dt            391711 non-null  float64
#  6   init_fda_dt       412702 non-null  int64
#  7   fda_dt            412702 non-null  int64
#  8   rept_cod          412702 non-null  object
#  9   auth_num          14188 non-null   object
#  10  mfr_num           391713 non-null  object
#  11  mfr_sndr          412701 non-null  object
#  12  lit_ref           21886 non-null   object
#  13  age               228738 non-null  float64
#  14  age_cod           228738 non-null  object
#  15  age_grp           86890 non-null   object
# ...

# %%
demographic['event_dt'].isnull().sum()
# Out:
# 201152

# %% [markdown]
# #Check demographic dataset variance

# %%
print(demographic.var())
# Out:
# primaryid      4.655887e+15
# caseid         3.356955e+11
# caseversion    2.180579e+00
# event_dt       9.566904e+13
# mfr_dt         6.803958e+07
# init_fda_dt    3.622805e+07
# fda_dt         6.946449e+03
# age            2.164747e+06
# wt             7.396981e+02
# rept_dt        1.189556e+10
# dtype: float64
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_5140/199542775.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(demographic.var())

# %% [markdown]
# #GET 5 TOP FREQUENTLY VALUES

# %%
#take out top 5 reaction of the dataset reaction to initial analyzing

c = Counter(reaction['pt'])
c.most_common(5)
print ("",c.most_common(5))
# Out:
#  [('Drug ineffective', 19563), ('Death', 17346), ('Toxicity to various agents', 9383), ('Drug dose omission', 9201), ('Alopecia', 9078)]

# %%
#subset for demographic 
demo = demographic[["primaryid","event_dt","age","sex","wt","occr_country"]]
demo
#this is the list of important variables wich necessary for statistic analytics
# Out:
#         primaryid    event_dt   age  sex     wt occr_country
# 0       100035813  20140110.0   NaN  NaN    NaN           US
# 1       100048965         NaN  64.0    F    NaN           US
# 2       100054258  20130701.0  71.0    M   59.0           JP
# 3       100058884      2011.0  54.0    M  108.0           US
# 4       100060834      2014.0   NaN    F    NaN           US
# ...           ...         ...   ...  ...    ...          ...
# 412697   99965822  20131219.0  75.0    M    NaN           GB
# 412698   99979614  20110311.0  50.0    M    NaN           DE
# 412699   99991303  20120911.0  66.0    F    NaN           CA
# 412700  999913117  20120823.0  53.0    M    NaN           US
# 412701   99994482         NaN  64.0    M    NaN           US
#
# [412702 rows x 6 columns]

# %%
react = reaction[["primaryid","pt"]]
react
# Out:
#          primaryid                           pt
# 0        100035813         Blood count abnormal
# 2        100048965        Drug hypersensitivity
# 3        100054258      Acute coronary syndrome
# 7        100058884  Acute myocardial infarction
# 27       100060834          Psychiatric symptom
# ...            ...                          ...
# 1206248   99965822          Metastatic neoplasm
# 1206250   99979614    Cardio-respiratory arrest
# 1206254   99991303                    Pneumonia
# 1206255  999913117         Basal cell carcinoma
# 1206257   99994482               Prostatomegaly
#
# [412702 rows x 2 columns]

# %% [markdown]
# #STATISTICAL METHOD

# %%
#merge reaction and drug key = primaryid
reactiondrug = pd.merge(drug,reaction,left_on='primaryid',right_on='primaryid',how='left')
reactiondrug
# Out:
#          primaryid  caseid_x  drug_seq role_cod                drugname  \
# 0        100035813  10003581         1       PS                  JAKAFI
# 1        100035813  10003581         2       SS                  JAKAFI
# 2        100035813  10003581         3       SS                  JAKAFI
# 3        100035813  10003581         4        C             METOPROLOL.
# 4        100035813  10003581         5        C              LORAZEPAM.
# ...            ...       ...       ...      ...                     ...
# 1686456  999913117   9999131        10        C  CLOBETASOL PROPIONATE.
# 1686457  999913117   9999131        11        C               SORIATANE
# 1686458   99994482   9999448         1       PS                LUMIZYME
# 1686459   99994482   9999448         2       SS                LUMIZYME
# 1686460   99994482   9999448         3        C               FENTANYL.
#
#                        prod_ai  val_vbm             route  \
# ...

# %%
reactiondrug.pt.nunique()
# Out:
# 7456

# %%
#create dummies variables for reaction 'DEATH'
diedummies = pd.get_dummies(reactiondrug['pt']== 'Death')
diedummies.head(10)
# Out:
#    False  True
# 0      1     0
# 1      1     0
# 2      1     0
# 3      1     0
# 4      1     0
# 5      1     0
# 6      1     0
# 7      1     0
# 8      1     0
# 9      1     0

# %%
# rename the dummies by 'NoDeath' and 'Death'
reactdummies = diedummies.rename(columns={False: "NoDeath", True: "Death"})
reactdummies
# Out:
#          NoDeath  Death
# 0              1      0
# 1              1      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 1686456        1      0
# 1686457        1      0
# 1686458        1      0
# 1686459        1      0
# 1686460        1      0
#
# [1686461 rows x 2 columns]

# %%
#merge table drugreaction with dummy table 
drugreactdeath = pd.concat([reactiondrug, reactdummies], axis=1)
drugreactdeath
# Out:
#          primaryid  caseid_x  drug_seq role_cod                drugname  \
# 0        100035813  10003581         1       PS                  JAKAFI
# 1        100035813  10003581         2       SS                  JAKAFI
# 2        100035813  10003581         3       SS                  JAKAFI
# 3        100035813  10003581         4        C             METOPROLOL.
# 4        100035813  10003581         5        C              LORAZEPAM.
# ...            ...       ...       ...      ...                     ...
# 1686456  999913117   9999131        10        C  CLOBETASOL PROPIONATE.
# 1686457  999913117   9999131        11        C               SORIATANE
# 1686458   99994482   9999448         1       PS                LUMIZYME
# 1686459   99994482   9999448         2       SS                LUMIZYME
# 1686460   99994482   9999448         3        C               FENTANYL.
#
#                        prod_ai  val_vbm             route  \
# ...

# %%
#perc = 50.0 
#min_count =  int(((100-perc)/100)*demographic.shape[1] + 1)
#demographic = demographic.dropna( axis=0, thresh=min_count)

# %%
drugreactdeath = pd.concat([reactiondrug, reactdummies], axis=1)
drugreactdeath
# Out:
#          primaryid  caseid_x  drug_seq role_cod                drugname  \
# 0        100035813  10003581         1       PS                  JAKAFI
# 1        100035813  10003581         2       SS                  JAKAFI
# 2        100035813  10003581         3       SS                  JAKAFI
# 3        100035813  10003581         4        C             METOPROLOL.
# 4        100035813  10003581         5        C              LORAZEPAM.
# ...            ...       ...       ...      ...                     ...
# 1686456  999913117   9999131        10        C  CLOBETASOL PROPIONATE.
# 1686457  999913117   9999131        11        C               SORIATANE
# 1686458   99994482   9999448         1       PS                LUMIZYME
# 1686459   99994482   9999448         2       SS                LUMIZYME
# 1686460   99994482   9999448         3        C               FENTANYL.
#
#                        prod_ai  val_vbm             route  \
# ...

# %%
#create subset with condition only take records have DEATH = 1
DiedDummies = drugreactdeath[drugreactdeath['Death'] == 1]
DiedDummies
# Out:
#          primaryid  caseid_x  drug_seq role_cod  \
# 1500     101557293  10155729         1       SS
# 1501     101557293  10155729         2       PS
# 1502     101557293  10155729         3       SS
# 1522     101582082  10158208         1       PS
# 1523     101582082  10158208         2       SS
# ...            ...       ...       ...      ...
# 1683699   97048163   9704816         1       PS
# 1683700   97048163   9704816         2       SS
# 1684706   98172042   9817204         1       PS
# 1684707   98172042   9817204         2        C
# 1685155   98664264   9866426         1       PS
#
#                                        drugname  \
# 1500                              AZATHIOPRINE.
# 1501                              PREDNISOLONE.
# 1502                                    ADOPORT
# 1522                              PREDNISOLONE.
# 1523                              AZATHIOPRINE.
# ...                                         ...
# ...

# %%
# count the top 5 drugs which most frequency cause ppl died
s = Counter(DiedDummies['drugname'])
s.most_common(5)
print ("",s.most_common(5))
# Out:
#  [('OPANA ER', 4871), ('EYLEA', 2748), ('PERCOCET', 2661), ('OXYCONTIN', 2651), ('OPANA', 2639)]

# %%
#take out the drug Opana ER
opana = drugreactdeath[drugreactdeath['drugname'] == 'OPANA ER']
opana
# Out:
#          primaryid  caseid_x  drug_seq role_cod  drugname  \
# 89497    130049782  13004978        13        C  OPANA ER
# 92129    130511492  13051149         1       PS  OPANA ER
# 92136    130512492  13051249         1       PS  OPANA ER
# 92137    130512492  13051249         2       SS  OPANA ER
# 92138    130512492  13051249         3       SS  OPANA ER
# ...            ...       ...       ...      ...       ...
# 1655362  146950771  14695077         2       SS  OPANA ER
# 1655382  146950781  14695078         1       PS  OPANA ER
# 1655383  146950781  14695078         2       SS  OPANA ER
# 1655403  146950791  14695079         1       PS  OPANA ER
# 1655404  146950791  14695079         2       SS  OPANA ER
#
#                            prod_ai  val_vbm    route              dose_vbm  \
# 89497    OXYMORPHONE HYDROCHLORIDE        1      NaN            20 MG, UNK
# 92129    OXYMORPHONE HYDROCHLORIDE        1     Oral            20 MG, BID
# ...

# %%
from tabulate import tabulate

## column for reaction and row for drug
crosstable = [{'crosstable','0', '1'},
          {0, 386762, 14707},
          {1, 8594, 2639}]
print(tabulate(crosstable))
# Out:
# ----------  ------  -----
# crosstable       0      1
# 0           386762  14707
# 1             8594   2639
# ----------  ------  -----

# %% [markdown]
# # MACHINE LEARNING METHOD
#
#
#
#
# **văn bản in đậm**

# %%
#perc = 25.0 
#min_count =  int(((100-perc)/100)*demographic.shape[1] + 1)
#mod_df = demographic.dropna( axis=0,thresh=min_count)

# %%
#mod_df['event_dt'] = mod_df['event_dt'].astype(int)

# %% [markdown]
# ##DATA CLEANING DEMOGRAPHIC DATASET

# %%
demo1 = demographic[['primaryid','age','age_cod','age_grp','sex','wt','wt_cod','occr_country']]
demo1.head(10)
# Out:
#    primaryid   age age_cod age_grp  sex      wt wt_cod occr_country
# 0  100035813   NaN     NaN     NaN  NaN     NaN    NaN           US
# 1  100048965  64.0      YR     NaN    F     NaN    NaN           US
# 2  100054258  71.0      YR     NaN    M   59.00     KG           JP
# 3  100058884  54.0      YR     NaN    M  108.00     KG           US
# 4  100060834   NaN     NaN     NaN    F     NaN    NaN           US
# 5  100065478  36.0      YR       A    F   90.70     KG           US
# 6  100066292   NaN     NaN     NaN    M     NaN    NaN           US
# 7  100071964  75.0      YR       E    M     NaN    NaN           US
# 8  100100246  56.0      YR     NaN    M     NaN    NaN           DE
# 9  100113852  73.0      YR       E    F   58.97     KG           US

# %%
demo1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412702 entries, 0 to 412701
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   primaryid     412702 non-null  int64
#  1   age           228738 non-null  float64
#  2   age_cod       228738 non-null  object
#  3   age_grp       86890 non-null   object
#  4   sex           350236 non-null  object
#  5   wt            79134 non-null   float64
#  6   wt_cod        79134 non-null   object
#  7   occr_country  412688 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.3+ MB

# %%
print(demo1.age_cod.unique())
# Out:
# [nan 'YR' 'WK' 'MON' 'DY' 'HR' 'DEC']

# %%
demo1.isnull().sum()
# Out:
# primaryid            0
# age             183964
# age_cod         183964
# age_grp         325812
# sex              62466
# wt              333568
# wt_cod          333568
# occr_country        14
# dtype: int64

# %% [markdown]
# ##CLEANING AGE VARIABLE

# %%
demo1.age_cod.value_counts()
# Out:
# YR     224314
# DEC      1476
# DY       1433
# MON      1413
# WK         97
# HR          5
# Name: age_cod, dtype: int64

# %%
plt.figure(figsize = (15,10)) 
sns.boxplot(demo1.age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
ageoutlier2 = demo1['age_cod'][(demo1['age_cod']) != 'YR'].index

# %%
len(ageoutlier2)
# Out:
# 188388

# %%
demo1 = demo1.drop(ageoutlier2)

# %%
len(demo1)
# Out:
# 224314

# %%
plt.figure(figsize = (15,10))
sns.boxplot(demo1.age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
plt.figure(figsize = (10,5))
sns.histplot(demo1['age'],bins=10)
plt.title('Age of patients')
plt.tight_layout
#plt.savefig('histplot.jpg')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##CLEANING WEIGHT VARIABLE

# %%
plt.figure(figsize = (10,5))
sns.boxplot(demo1.wt)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='wt'>

# %%
print(demo1.wt_cod.unique())
# Out:
# [nan 'KG' 'LBS']

# %%
demo1.wt_cod.value_counts()
# Out:
# KG     62878
# LBS      296
# Name: wt_cod, dtype: int64

# %%
wtoutlier2 = demo1['wt_cod'][(demo1['wt_cod']) == 'LBS'].index
len(wtoutlier2)
# Out:
# 296

# %%
demo1 = demo1.drop(wtoutlier2)

# %%
demo1['wt'] = demo1['wt'].dropna()

# %%
demo1 = demo1.dropna(subset=['wt'])

# %%
print(demo1)
# Out:
#         primaryid   age age_cod age_grp sex      wt wt_cod occr_country
# 2       100054258  71.0      YR     NaN   M   59.00     KG           JP
# 3       100058884  54.0      YR     NaN   M  108.00     KG           US
# 5       100065478  36.0      YR       A   F   90.70     KG           US
# 9       100113852  73.0      YR       E   F   58.97     KG           US
# 12      100121125  62.0      YR     NaN   M   70.60     KG           FR
# ...           ...   ...     ...     ...  ..     ...    ...          ...
# 412677   99728372  87.0      YR     NaN   F   80.00     KG           FR
# 412679  997606822  80.0      YR     NaN   F   83.90     KG           US
# 412683  998316911  77.0      YR     NaN   M  106.00     KG           DE
# 412687  998862514  68.0      YR     NaN   M   49.00     KG           CN
# 412688   99901672  29.0      YR     NaN   F   81.72     KG           US
#
# [62878 rows x 8 columns]

# %%
demo1['wt'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (10,5))
sns.boxplot(demo1['wt'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='wt'>

# %%
demo1.to_csv('asd.csv')

# %%
median = np.median(demo1.wt)
median

Q1 = demo1.wt.quantile(0.25)
print(demo1)
Q3 = demo1.wt.quantile(0.75)
IQR = Q3 - Q1
LowerQ = Q1 -(1.5 *IQR)
UpperQ = Q3 +(1.5 * IQR)

index = demo1['wt'][(demo1['wt']> UpperQ)|(demo1['wt']< LowerQ) ].index
demo1 = demo1.drop(index)

sns.boxplot (x='wt',data=demo1)
plt.tight_layout()
#plt.savefig('boxplot cleaned.jpg')
plt.show
# Out:
#         primaryid   age age_cod age_grp sex      wt wt_cod occr_country
# 2       100054258  71.0      YR     NaN   M   59.00     KG           JP
# 3       100058884  54.0      YR     NaN   M  108.00     KG           US
# 5       100065478  36.0      YR       A   F   90.70     KG           US
# 9       100113852  73.0      YR       E   F   58.97     KG           US
# 12      100121125  62.0      YR     NaN   M   70.60     KG           FR
# ...           ...   ...     ...     ...  ..     ...    ...          ...
# 412677   99728372  87.0      YR     NaN   F   80.00     KG           FR
# 412679  997606822  80.0      YR     NaN   F   83.90     KG           US
# 412683  998316911  77.0      YR     NaN   M  106.00     KG           DE
# 412687  998862514  68.0      YR     NaN   M   49.00     KG           CN
# 412688   99901672  29.0      YR     NaN   F   81.72     KG           US
#
# [62878 rows x 8 columns]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#demo1['wt'].fillna((demo1['wt'].mean()), inplace=True)

# %%
plt.figure(figsize = (15,10))
sns.histplot(demo1['wt'],bins=10)
plt.title('Age of patients')
plt.tight_layout
#plt.savefig('histplot.jpg')
plt.subplot(1,2,2)
sns.distplot(demo1['wt'])
plt.show
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##CLEANING SEX VARIBALE

# %%
demo1.sex.value_counts()
# Out:
# F      37043
# M      23440
# UNK        3
# Name: sex, dtype: int64

# %%
demo1['sex'] = demo1['sex'].astype('category')

# %% [markdown]
# Drug

# %%
sexoutlier2 = demo1['sex'][(demo1['sex']) == 'UNK'].index

# %%
demo1 = demo1.drop(sexoutlier2)

# %%
demo1.sex.isnull().sum()
# Out:
# 254

# %%
demo1 = demo1.dropna(subset=['sex'])

# %%
demo1.to_csv('demo1.csv')

# %%
female = demo1.sex[demo1['sex']== 'F'].count()
male = demo1.sex[demo1['sex']== 'M'].count()


labels = ['female', 'male']
slices = [female, male]
explode = [0,0.1]

plt.pie(slices,labels=labels, shadow = True,
        startangle = 20,#the angle
        autopct = '%1.1f%%',#decimal = 1
        wedgeprops= {'edgecolor': 'White'})
plt.axis('equal')#equal aspect ratio ensures that pie is drawn as a circle.
plt.title('sex pie distribution')
plt.legend()
plt.tight_layout()#used for default padding
#plt.savefig('Churn.jpg')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##CLEANING COUNTRY VARIABLE

# %%
print(demo1.occr_country.unique())
# Out:
# ['JP' 'US' 'FR' 'CA' 'DE' 'CO' 'CN' 'GB' 'AU' 'ML' 'MX' 'RU' 'IT' 'PR'
#  'ES' 'BR' 'KR' 'NL' 'HK' 'SK' 'IE' 'BE' 'CZ' 'GR' 'CH' 'TW' 'TH' 'PT'
#  'PE' 'AT' 'MY' 'DK' 'IL' 'RO' 'SG' 'CR' 'AR' 'SE' 'HR' 'PL' 'UA' 'TR'
#  'SI' 'SN' 'HU' 'ID' 'NO' 'AM' 'LB' 'IN' 'DZ' 'NZ' 'UG' 'FI' 'ZA' 'LS'
#  'EG' 'BS' 'KW' 'LT' 'MW' 'ET' 'RS' 'IR' 'CL' 'BD' 'KZ' 'BY' 'KE' 'PK'
#  'EE' 'SA' 'LU' 'PA' 'TN' 'VI' 'KG' 'EC' 'MM' 'BN' 'GT' 'BG' 'BI' 'PH'
#  'HT' 'VN' 'AE' 'IS' 'CY' 'VE' 'IQ' 'TT' 'GE' 'BA' 'QA' 'OM' 'AS' 'AF' nan
#  'NG' 'FO' 'LK' 'CU' 'MA' 'LV' 'DO' 'HN' 'AZ' 'PG' 'JO' 'SV' 'ZW' 'UM'
#  'KH' 'MT' 'SY' 'AX' 'MK' 'ME' 'CI' 'JM']

# %%
demo1['occr_country'].isnull().sum()
# Out:
# 2

# %%
demo1 = demo1.dropna(subset=['occr_country'])

# %%
demo1['occr_country'] = demo['occr_country'].astype('category')

# %%
plt.figure(figsize = (20,10))
sns.countplot(x= 'occr_country',data= demo1)
#plt.savefig('Country ')
# Out:
# <AxesSubplot:xlabel='occr_country', ylabel='count'>

# %%
# count the top 5 drugs which most frequency cause ppl died
c = Counter(demo1['occr_country'])
c = c.most_common(10)
print ("",c)
# Out:
#  [('US', 34307), ('FR', 6275), ('GB', 3212), ('DE', 3169), ('JP', 3085), ('CA', 1811), ('BR', 979), ('IT', 830), ('CN', 712), ('ES', 684)]

# %%
demo1['occr_country'].sort_values(ascending = True).value_counts()[:10].plot(kind='bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
demo1['country'] = demo1['occr_country'].apply(lambda x:1 if x == 'US' else 2)

# %%
demo1 = demo1.drop(['occr_country'],axis = 1)

# %%
demo1['sex'] = demo1['sex'].apply(lambda x:1 if x == 'M' else 0)
demo1['wt'] =demo1['wt'].astype(int)
demo1['age'] =demo1['age'].astype(int)
demo1
# Out:
#         primaryid  age age_cod age_grp  sex   wt wt_cod  country
# 2       100054258   71      YR     NaN    1   59     KG        2
# 3       100058884   54      YR     NaN    1  108     KG        1
# 5       100065478   36      YR       A    0   90     KG        1
# 9       100113852   73      YR       E    0   58     KG        1
# 12      100121125   62      YR     NaN    1   70     KG        2
# ...           ...  ...     ...     ...  ...  ...    ...      ...
# 412677   99728372   87      YR     NaN    0   80     KG        2
# 412679  997606822   80      YR     NaN    0   83     KG        1
# 412683  998316911   77      YR     NaN    1  106     KG        2
# 412687  998862514   68      YR     NaN    1   49     KG        2
# 412688   99901672   29      YR     NaN    0   81     KG        1
#
# [60481 rows x 8 columns]

# %% [markdown]
# #CLSUTERING

# %% [markdown]
# ##GENERATING 15000 SAMPLES FROM THE DATASET.(CLUSTERING PART CAN'T SOLVE TOO MANY OBSERVATIONS)

# %%
sam1 = demo1.sample(n = 15000,random_state = 42 )
sam1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 86231 to 121014
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   primaryid  15000 non-null  int64
#  1   age        15000 non-null  int32
#  2   age_cod    15000 non-null  object
#  3   age_grp    3217 non-null   object
#  4   sex        15000 non-null  int64
#  5   wt         15000 non-null  int32
#  6   wt_cod     15000 non-null  object
#  7   country    15000 non-null  int64
# dtypes: int32(2), int64(3), object(3)
# memory usage: 937.5+ KB

# %%
sam2 = sam1[['age','sex','wt','country']]
sam2
# Out:
#         age  sex  wt  country
# 86231    56    0  62        2
# 48273    27    0  72        1
# 2180     65    1  77        1
# 372624   78    0  68        1
# 354793   71    0  36        1
# ...     ...  ...  ..      ...
# 289491   59    0  55        2
# 46049    68    0  49        2
# 385342   64    0  58        2
# 2622     66    0  67        1
# 121014   57    0  65        1
#
# [15000 rows x 4 columns]

# %%
from sklearn.neighbors import NearestNeighbors
def get_kdist_plot(X=None, k=None, radius_nbrs=1.0):

    nbrs = NearestNeighbors(n_neighbors=k, radius=radius_nbrs).fit(X)

    # For each point, compute distances to its k-nearest neighbors
    distances, indices = nbrs.kneighbors(X) 
                                       
    distances = np.sort(distances, axis=0)
    distances = distances[:, k-1]

    # Plot the sorted K-nearest neighbor distance for each point in the dataset
    plt.figure(figsize=(8,8))
    plt.plot(distances)
    plt.xlabel('Points/Objects in the dataset', fontsize=12)
    plt.ylabel('Sorted {}-nearest neighbor distance'.format(k), fontsize=12)
    plt.grid(True, linestyle="--", color='black', alpha=0.4)
    plt.show()
    plt.close()


k = 2 * 4 - 1 # k=2*{dim(dataset)} - 1

# %%
get_kdist_plot(X=sam2, k=k)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

clustering = DBSCAN(eps=3, min_samples=5).fit(sam2)
clustering.labels_
clustering
# Out:
# DBSCAN(eps=3)

# %%
labels=clustering.labels_
N_clus=len(set(labels))-(1 if -1 in labels else 0)
print('Estimated no. of clusters: %d' % N_clus)
# Out:
# Estimated no. of clusters: 3

# %%
sam2['country'] = sam2['country'].astype(int)
sam2['sex'] = sam2['sex'].astype(int)
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_5140/2667392166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sam2['country'] = sam2['country'].astype(int)
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_5140/2667392166.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sam2['sex'] = sam2['sex'].astype(int)

# %%
from matplotlib import rcParams
#WE CHECK SAMPLE DATASET AND HOW IT DISTRIBUTED 
rcParams['figure.figsize'] = 20,10
g = sns.pairplot(sam2)
g.map_upper(sns.kdeplot,fill=True, thresh=0, levels=100, cmap="mako");

# %%
sam2a= sam2.iloc[:,:].values
sam2a
# Out:
# array([[56,  0, 62,  2],
#        [27,  0, 72,  1],
#        [65,  1, 77,  1],
#        ...,
#        [64,  0, 58,  2],
#        [66,  0, 67,  1],
#        [57,  0, 65,  1]])

# %% [markdown]
# ##DENDOGRAM (hierarchical clustering)**văn bản in đậm**

# %%
import scipy.cluster.hierarchy as sch
plt.figure( figsize= (15,8))
dendrogram = sch.dendrogram(sch.linkage(sam2,method = 'ward'))
#WE HAVE 3 CLUSTERS IN THE PLOT
plt.title('Dendrogram')
plt.xlabel('patients')
plt.ylabel('Euclidean distances')
plt.axhline(y=1500, color='r', linestyle='--')
plt.show()

# %% [markdown]
# Hierarchical Cluster cluster data by best matched pair. that means the smaller pair the bigger similar each of them so in order to get the number of clusters we have to check the farthest distance it can go.

# %%
from sklearn.cluster import KMeans
wcss = [] 
for i in range(1, 10): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(sam2a) 
    wcss.append(kmeans.inertia_)
    #Inertia: It is the sum of squared distances of samples to their closest cluster center.

# %% [markdown]
# ##+KMEANS CLUTERING

# %%
plt.figure(figsize= (10,5))
plt.plot(range(1,10), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

# %%
kmeans = KMeans(n_clusters =3, init = 'k-means++', random_state = 42)
y_kmeans =kmeans.fit_predict(sam2a)

# %%
#BOTH CLUSTERING CHECK SHOW THAT WE HAVE 3 CLUSTERS IN THIS DATASET
Kmeanss =  kmeans.cluster_centers_
Kmeanss
# Out:
# array([[69.43821544,  0.33563252, 64.054887  ,  1.47886704],
#        [30.90448286,  0.3105772 , 61.21828304,  1.48256666],
#        [58.57867169,  0.52964592, 96.12109784,  1.32369579]])

# %% [markdown]
# ##MERGE THE CLUSTERS CLASSIFICATION TO DATASET

# %%
sam1['cluster'] = kmeans.labels_
sam1
# Out:
#         primaryid  age age_cod age_grp  sex  wt wt_cod  country  cluster
# 86231   143485691   56      YR     NaN    0  62     KG        2        0
# 48273   140961033   27      YR     NaN    0  72     KG        1        1
# 2180    113503643   65      YR     NaN    1  77     KG        1        0
# 372624  146567751   78      YR       E    0  68     KG        1        0
# 354793  146368461   71      YR     NaN    0  36     KG        1        0
# ...           ...  ...     ...     ...  ...  ..    ...      ...      ...
# 289491  145643291   59      YR       A    0  55     KG        2        0
# 46049   140355614   68      YR     NaN    0  49     KG        2        0
# 385342  146717071   64      YR     NaN    0  58     KG        2        0
# 2622    115863233   66      YR     NaN    0  67     KG        1        0
# 121014  143855871   57      YR       A    0  65     KG        1        0
#
# [15000 rows x 9 columns]

# %%
plt.figure(figsize = (20,10))
sns.countplot(x='cluster',data= sam1)
#total clusters in the sample dataset
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='count'>

# %%
sam1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 86231 to 121014
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   primaryid  15000 non-null  int64
#  1   age        15000 non-null  int32
#  2   age_cod    15000 non-null  object
#  3   age_grp    3217 non-null   object
#  4   sex        15000 non-null  int64
#  5   wt         15000 non-null  int32
#  6   wt_cod     15000 non-null  object
#  7   country    15000 non-null  int64
#  8   cluster    15000 non-null  int32
# dtypes: int32(3), int64(3), object(3)
# memory usage: 1.5+ MB

# %%
sam1.to_csv('sample1.csv')

# %% [markdown]
# ##CLUSTERING PLOT

# %%
rcParams['figure.figsize'] = 20,10
sns.scatterplot(data=sam1, x="age", y="wt", hue="cluster",sizes = [150,50])
# Out:
# <AxesSubplot:xlabel='age', ylabel='wt'>

# %%
#ax.set_xlabel('age Label')
#ax.set_ylabel('weight Label')
#ax.set_zlabel('gender Label')
#ax.scatter(x, y, z, c=A, marker='o')

# %%
#A

# %%
from mpl_toolkits import mplot3d

z = sam1['sex']
x = sam1['age']
y = sam1['wt']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#A = (z <=0)
ax.scatter(x, y, z, c=z, marker='o')
ax.set_xlabel('age Label')
ax.set_ylabel('weight Label')
ax.set_zlabel('gender Label')

plt.show()

# %%
sam2
# Out:
#         age  sex  wt  country
# 86231    56    0  62        2
# 48273    27    0  72        1
# 2180     65    1  77        1
# 372624   78    0  68        1
# 354793   71    0  36        1
# ...     ...  ...  ..      ...
# 289491   59    0  55        2
# 46049    68    0  49        2
# 385342   64    0  58        2
# 2622     66    0  67        1
# 121014   57    0  65        1
#
# [15000 rows x 4 columns]

# %%
A = (z<=0)

# %%
from matplotlib import animation
def animate_func(num):
    ax.clear()  # Clears the figure to update the line, point,   
                # title, and axes
    # Updating Trajectory Line (num+1 due to Python indexing)
    ax.plot3D(sam2[0, :num+1], sam2[1, :num+1], 
              sam2[2, :num+1], c='blue')
    # Updating Point Location 
    ax.scatter(sam2[0, num], sam2[1, num], dataSet[2, num], 
               c='blue', marker='o')
    # Adding Constant Origin
    ax.plot3D(sam2[0, 0], sam2[1, 0], sam2[2, 0],     
               c='black', marker='o')
    # Setting Axes Limits
    ax.set_xlim3d([-1, 1])
    ax.set_ylim3d([-1, 1])
    ax.set_zlim3d([0, 100])

    # Adding Figure Labels
    ax.set_title('Trajectory \nTime = ' + str(np.round(t[num],    
                 decimals=2)) + ' sec')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

# %%
t = np.linspace(0, 20, 100)
numDataPoints = len(t)

# %%
# Plotting the Animation
fig = plt.figure()
ax = plt.axes(projection='3d')
line_ani = animation.FuncAnimation(fig, animate_func, interval=100,   
                                   frames=numDataPoints)
plt.show()

# %%
z1= sam2['country']
x1 = sam2['age']
y1 = sam2['wt']
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, y1, z1, c = z, cmap = 'coolwarm')
colormap = np.array(['r', 'g', 'b'])
ax.set_xlabel('age Label',)
ax.set_ylabel('weight Label')
ax.set_zlabel('country Label')

plt.show()

# %%
#make 2 three-d plots where x(age) and y(wt) is same but change z to gender and country

# %%
rcParams['figure.figsize'] = 20,10
sns.scatterplot(data=sam1, x="country", y="sex", hue="cluster",sizes = [150,50])
# Out:
# <AxesSubplot:xlabel='country', ylabel='sex'>

# %%
rcParams['figure.figsize'] = 20,10
sns.scatterplot(data=sam1, x="age", y="country", hue="cluster",sizes = [150,50])
# Out:
# <AxesSubplot:xlabel='age', ylabel='country'>

# %% [markdown]
# #DRUG DATASET

# %%
drug1 = drug[["primaryid","dechal","rechal","drugname",'prod_ai']]
drug1
# Out:
#          primaryid dechal rechal                drugname  \
# 0        100035813    NaN      U                  JAKAFI
# 1        100035813    NaN      U                  JAKAFI
# 2        100035813    NaN      U                  JAKAFI
# 3        100035813    NaN    NaN             METOPROLOL.
# 4        100035813    NaN    NaN              LORAZEPAM.
# ...            ...    ...    ...                     ...
# 1686456  999913117      D    NaN  CLOBETASOL PROPIONATE.
# 1686457  999913117      D    NaN               SORIATANE
# 1686458   99994482    NaN    NaN                LUMIZYME
# 1686459   99994482    NaN    NaN                LUMIZYME
# 1686460   99994482    NaN    NaN               FENTANYL.
#
#                        prod_ai
# 0                  RUXOLITINIB
# 1                  RUXOLITINIB
# 2                  RUXOLITINIB
# 3                   METOPROLOL
# 4                    LORAZEPAM
# ...                        ...
# 1686456  CLOBETASOL PROPIONATE
# ...

# %%
drug1['drugname'] = drug1['drugname'].astype('category')
drug1['prod_ai'] = drug1['prod_ai'].astype('category')
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_5140/684525064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug1['drugname'] = drug1['drugname'].astype('category')
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_5140/684525064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug1['prod_ai'] = drug1['prod_ai'].astype('category')

# %%
drug1 =drug1.drop(['dechal','rechal'],axis = 1)

# %%
drug2 = drug1.drop(['primaryid','prod_ai'],axis =1)

# %%
drug2 = drug2.iloc[:,:].values

# %%
patientinfo = pd.concat([sam1, reactdummies], axis=1)

# %%
patientinfo = pd.merge(sam1,drug1,left_on='primaryid',right_on='primaryid',how='left')

# %%
patientinfo
# Out:
#        primaryid  age age_cod age_grp  sex  wt wt_cod  country  cluster  \
# 0      143485691   56      YR     NaN    0  62     KG        2        0
# 1      140961033   27      YR     NaN    0  72     KG        1        1
# 2      113503643   65      YR     NaN    1  77     KG        1        0
# 3      113503643   65      YR     NaN    1  77     KG        1        0
# 4      146567751   78      YR       E    0  68     KG        1        0
# ...          ...  ...     ...     ...  ...  ..    ...      ...      ...
# 91375  143855871   57      YR       A    0  65     KG        1        0
# 91376  143855871   57      YR       A    0  65     KG        1        0
# 91377  143855871   57      YR       A    0  65     KG        1        0
# 91378  143855871   57      YR       A    0  65     KG        1        0
# 91379  143855871   57      YR       A    0  65     KG        1        0
#
#                       drugname                                  prod_ai
# ...

# %%
patientinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91380 entries, 0 to 91379
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   primaryid  91380 non-null  int64
#  1   age        91380 non-null  int32
#  2   age_cod    91380 non-null  object
#  3   age_grp    17758 non-null  object
#  4   sex        91380 non-null  int64
#  5   wt         91380 non-null  int32
#  6   wt_cod     91380 non-null  object
#  7   country    91380 non-null  int64
#  8   cluster    91380 non-null  int32
#  9   drugname   91379 non-null  category
#  10  prod_ai    88629 non-null  category
# dtypes: category(2), int32(3), int64(3), object(3)
# memory usage: 9.0+ MB

# %% [markdown]
# ##translate drug name into categories number

# %%
d = dict(enumerate(patientinfo['drugname'].cat.categories))
#print (d)

# %%
f = dict(enumerate(patientinfo['prod_ai'].cat.categories))
#print (f)

# %%
patientinfo['drugname'] =  patientinfo['drugname'].cat.codes
patientinfo['prod_ai']= patientinfo['prod_ai'].cat.codes

# %%
patientinfo['drugname'] = patientinfo['drugname'].astype('category')
patientinfo['prod_ai']= patientinfo['prod_ai'].astype('category')

# %%
patientinfo
# Out:
#        primaryid  age age_cod age_grp  sex  wt wt_cod  country  cluster  \
# 0      143485691   56      YR     NaN    0  62     KG        2        0
# 1      140961033   27      YR     NaN    0  72     KG        1        1
# 2      113503643   65      YR     NaN    1  77     KG        1        0
# 3      113503643   65      YR     NaN    1  77     KG        1        0
# 4      146567751   78      YR       E    0  68     KG        1        0
# ...          ...  ...     ...     ...  ...  ..    ...      ...      ...
# 91375  143855871   57      YR       A    0  65     KG        1        0
# 91376  143855871   57      YR       A    0  65     KG        1        0
# 91377  143855871   57      YR       A    0  65     KG        1        0
# 91378  143855871   57      YR       A    0  65     KG        1        0
# 91379  143855871   57      YR       A    0  65     KG        1        0
#
#       drugname prod_ai
# 0        33626    3311
# 1        32962    2375
# 2        45409    4949
# ...

# %%
patientinfo['sex'] = patientinfo['sex'].astype('category')

# %%
#patientinfo['sex']= patientinfo['sex'].apply(lambda x:0 if x == 'M' else 1)

# %%
patientinfo
# Out:
#        primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0      143485691   56      YR     NaN   0  62     KG        2        0
# 1      140961033   27      YR     NaN   0  72     KG        1        1
# 2      113503643   65      YR     NaN   1  77     KG        1        0
# 3      113503643   65      YR     NaN   1  77     KG        1        0
# 4      146567751   78      YR       E   0  68     KG        1        0
# ...          ...  ...     ...     ...  ..  ..    ...      ...      ...
# 91375  143855871   57      YR       A   0  65     KG        1        0
# 91376  143855871   57      YR       A   0  65     KG        1        0
# 91377  143855871   57      YR       A   0  65     KG        1        0
# 91378  143855871   57      YR       A   0  65     KG        1        0
# 91379  143855871   57      YR       A   0  65     KG        1        0
#
#       drugname prod_ai
# 0        33626    3311
# 1        32962    2375
# 2        45409    4949
# ...

# %%
patientinfo.duplicated().sum()
# Out:
# 16746

# %%
patientinfo.drop_duplicates()
# Out:
#        primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0      143485691   56      YR     NaN   0  62     KG        2        0
# 1      140961033   27      YR     NaN   0  72     KG        1        1
# 2      113503643   65      YR     NaN   1  77     KG        1        0
# 3      113503643   65      YR     NaN   1  77     KG        1        0
# 4      146567751   78      YR       E   0  68     KG        1        0
# ...          ...  ...     ...     ...  ..  ..    ...      ...      ...
# 91375  143855871   57      YR       A   0  65     KG        1        0
# 91376  143855871   57      YR       A   0  65     KG        1        0
# 91377  143855871   57      YR       A   0  65     KG        1        0
# 91378  143855871   57      YR       A   0  65     KG        1        0
# 91379  143855871   57      YR       A   0  65     KG        1        0
#
#       drugname prod_ai
# 0        33626    3311
# 1        32962    2375
# 2        45409    4949
# ...

# %%
ainull = patientinfo[patientinfo['prod_ai'] == -1].index
print(ainull)
# Out:
# Int64Index([   47,    73,    95,   186,   257,   277,   286,   299,   304,
#               319,
#             ...
#             91027, 91076, 91077, 91135, 91155, 91238, 91242, 91245, 91248,
#             91330],
#            dtype='int64', length=2751)

# %%
drugnull = patientinfo[patientinfo['drugname'] == -1].index
print(drugnull)
# Out:
# Int64Index([4737], dtype='int64')

# %%
patientinfo = patientinfo.drop(ainull,axis = 0)

# %%
patientinfo =patientinfo.drop_duplicates()
patientinfo
# Out:
#        primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0      143485691   56      YR     NaN   0  62     KG        2        0
# 1      140961033   27      YR     NaN   0  72     KG        1        1
# 2      113503643   65      YR     NaN   1  77     KG        1        0
# 3      113503643   65      YR     NaN   1  77     KG        1        0
# 4      146567751   78      YR       E   0  68     KG        1        0
# ...          ...  ...     ...     ...  ..  ..    ...      ...      ...
# 91375  143855871   57      YR       A   0  65     KG        1        0
# 91376  143855871   57      YR       A   0  65     KG        1        0
# 91377  143855871   57      YR       A   0  65     KG        1        0
# 91378  143855871   57      YR       A   0  65     KG        1        0
# 91379  143855871   57      YR       A   0  65     KG        1        0
#
#       drugname prod_ai
# 0        33626    3311
# 1        32962    2375
# 2        45409    4949
# ...

# %% [markdown]
# #REACTION DATASET

# %%
reaction = pd.read_csv('E:/New folder (5)/niesdang/REAC18Q1.csv',sep = '$')
reaction.head(10)
# Out:
#    primaryid    caseid                           pt drug_rec_act
# 0  100035813  10003581         Blood count abnormal          NaN
# 1  100035813  10003581        Haemoglobin decreased          NaN
# 2  100048965  10004896        Drug hypersensitivity          NaN
# 3  100054258  10005425      Acute coronary syndrome          NaN
# 4  100054258  10005425          Acute kidney injury          NaN
# 5  100054258  10005425            Cardiac tamponade          NaN
# 6  100054258  10005425          Respiratory failure          NaN
# 7  100058884  10005888  Acute myocardial infarction          NaN
# 8  100058884  10005888          Atrial fibrillation          NaN
# 9  100058884  10005888               Cardiac arrest          NaN

# %%
react = reaction.drop(['caseid','drug_rec_act'],axis = 1)
react.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206259 entries, 0 to 1206258
# Data columns (total 2 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   primaryid  1206259 non-null  int64
#  1   pt         1206259 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 18.4+ MB

# %%
reactdummies = pd.get_dummies(react['pt']== 'Death')
reactdummies.head(20)
# Out:
#     False  True
# 0       1     0
# 1       1     0
# 2       1     0
# 3       1     0
# 4       1     0
# 5       1     0
# 6       1     0
# 7       1     0
# 8       1     0
# 9       1     0
# 10      1     0
# 11      1     0
# 12      1     0
# 13      1     0
# 14      1     0
# 15      1     0
# 16      1     0
# 17      1     0
# 18      1     0
# 19      1     0

# %%
reactdummies = reactdummies.rename(columns={False: "NoDeath", True: "Death"})
reactdummies
# Out:
#          NoDeath  Death
# 0              1      0
# 1              1      0
# 2              1      0
# 3              1      0
# 4              1      0
# ...          ...    ...
# 1206254        1      0
# 1206255        1      0
# 1206256        1      0
# 1206257        1      0
# 1206258        1      0
#
# [1206259 rows x 2 columns]

# %%
drugreactdeath = pd.concat([react, reactdummies], axis=1)
drugreactdeath
# Out:
#          primaryid                       pt  NoDeath  Death
# 0        100035813     Blood count abnormal        1      0
# 1        100035813    Haemoglobin decreased        1      0
# 2        100048965    Drug hypersensitivity        1      0
# 3        100054258  Acute coronary syndrome        1      0
# 4        100054258      Acute kidney injury        1      0
# ...            ...                      ...      ...    ...
# 1206254   99991303                Pneumonia        1      0
# 1206255  999913117     Basal cell carcinoma        1      0
# 1206256  999913117  Squamous cell carcinoma        1      0
# 1206257   99994482           Prostatomegaly        1      0
# 1206258   99994482             Sluggishness        1      0
#
# [1206259 rows x 4 columns]

# %%
drugreactdeath = drugreactdeath.drop(['pt','NoDeath'],axis = 1)
drugreactdeath
# Out:
#          primaryid  Death
# 0        100035813      0
# 1        100035813      0
# 2        100048965      0
# 3        100054258      0
# 4        100054258      0
# ...            ...    ...
# 1206254   99991303      0
# 1206255  999913117      0
# 1206256  999913117      0
# 1206257   99994482      0
# 1206258   99994482      0
#
# [1206259 rows x 2 columns]

# %% [markdown]
# #FINAL DATASET

# %%
Finaldata = pd.merge(patientinfo ,drugreactdeath,left_on='primaryid',right_on='primaryid',how='left')
Finaldata
# Out:
#         primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0       143485691   56      YR     NaN   0  62     KG        2        0
# 1       143485691   56      YR     NaN   0  62     KG        2        0
# 2       143485691   56      YR     NaN   0  62     KG        2        0
# 3       143485691   56      YR     NaN   0  62     KG        2        0
# 4       140961033   27      YR     NaN   0  72     KG        1        1
# ...           ...  ...     ...     ...  ..  ..    ...      ...      ...
# 364151  143855871   57      YR       A   0  65     KG        1        0
# 364152  143855871   57      YR       A   0  65     KG        1        0
# 364153  143855871   57      YR       A   0  65     KG        1        0
# 364154  143855871   57      YR       A   0  65     KG        1        0
# 364155  143855871   57      YR       A   0  65     KG        1        0
#
#        drugname prod_ai  Death
# 0         33626    3311      0
# 1         33626    3311      0
# ...

# %%
Finaldata = Finaldata.drop_duplicates()
Finaldata
# Out:
#         primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0       143485691   56      YR     NaN   0  62     KG        2        0
# 4       140961033   27      YR     NaN   0  72     KG        1        1
# 7       113503643   65      YR     NaN   1  77     KG        1        0
# 9       113503643   65      YR     NaN   1  77     KG        1        0
# 11      146567751   78      YR       E   0  68     KG        1        0
# ...           ...  ...     ...     ...  ..  ..    ...      ...      ...
# 364126  143855871   57      YR       A   0  65     KG        1        0
# 364132  143855871   57      YR       A   0  65     KG        1        0
# 364138  143855871   57      YR       A   0  65     KG        1        0
# 364144  143855871   57      YR       A   0  65     KG        1        0
# 364150  143855871   57      YR       A   0  65     KG        1        0
#
#        drugname prod_ai  Death
# 0         33626    3311      0
# 4         32962    2375      0
# ...

# %%
Finaldata[Finaldata['Death'] == 1]
# Out:
#         primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 468     142902542   91      YR     NaN   1  83     KG        1        0
# 1598    143805701   91      YR     NaN   1  70     KG        2        0
# 2015    144999002   90      YR     NaN   1  77     KG        1        0
# 2016    144999002   90      YR     NaN   1  77     KG        1        0
# 2017    144999002   90      YR     NaN   1  77     KG        1        0
# ...           ...  ...     ...     ...  ..  ..    ...      ...      ...
# 350204  132474063   54      YR     NaN   0  86     KG        2        2
# 355220  144408371   73      YR     NaN   0  62     KG        1        0
# 355221  144408371   73      YR     NaN   0  62     KG        1        0
# 356150  144790422   83      YR     NaN   1  65     KG        1        0
# 364000  146717071   64      YR     NaN   0  58     KG        2        0
#
#        drugname prod_ai  Death
# 468       44764    1767      1
# 1598      27731    3264      1
# ...

# %%
plt.figure(figsize = (20,15))
sns.histplot(Finaldata['drugname'],bins=10)
#DRUG DISTRIBUTION
# Out:
# <AxesSubplot:xlabel='drugname', ylabel='Count'>

# %%
death = Finaldata.Death[Finaldata['Death']== 1].count()
nodeath = Finaldata.Death[Finaldata['Death'] == 0].count()


labels = ['death', 'nodeath']
slices = [death, nodeath]
explode = [0,0.1]

plt.pie(slices,labels=labels, shadow = True,
        startangle = 20,#the angle
        autopct = '%1.1f%%',#decimal = 1
        wedgeprops= {'edgecolor': 'White'})
plt.axis('equal')#equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Death event distribution',fontweight='bold', fontsize=15,c = 'c')
plt.legend()
plt.tight_layout()#used for default padding
#plt.savefig('Churn.jpg')
plt.show
#MY TARGET VARIABLE ISN'T BALANCED
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
death1 = Finaldata[Finaldata['Death']== 1]

# %%
plt.subplot(1, 2, 1)
plt.title('total  patient clusters in the dataset', fontweight='bold', fontsize=15)
sns.countplot(x='cluster',data= sam1)

plt.subplot(1, 2, 2)
plt.title('total number of dead patients by cluster', fontweight='bold', fontsize=15)
sns.countplot(x='cluster',data=death1 )
plt.show()

# %%
#@title 
#SCATTER PLOT OF DRUG NAME

rcParams['figure.figsize'] = 20,10
sns.scatterplot(data=Finaldata, x="drugname", y="prod_ai", hue="cluster",sizes = [150,50])
# Out:
# <AxesSubplot:xlabel='drugname', ylabel='prod_ai'>

# %%
cluster0 = Finaldata[Finaldata['cluster'] == 0]
cluster0
# Out:
#         primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0       143485691   56      YR     NaN   0  62     KG        2        0
# 7       113503643   65      YR     NaN   1  77     KG        1        0
# 9       113503643   65      YR     NaN   1  77     KG        1        0
# 11      146567751   78      YR       E   0  68     KG        1        0
# 13      146567751   78      YR       E   0  68     KG        1        0
# ...           ...  ...     ...     ...  ..  ..    ...      ...      ...
# 364126  143855871   57      YR       A   0  65     KG        1        0
# 364132  143855871   57      YR       A   0  65     KG        1        0
# 364138  143855871   57      YR       A   0  65     KG        1        0
# 364144  143855871   57      YR       A   0  65     KG        1        0
# 364150  143855871   57      YR       A   0  65     KG        1        0
#
#        drugname prod_ai  Death
# 0         33626    3311      0
# 7         45409    4949      0
# ...

# %%
#frequencies = ((frequencies))/len(frequencies)*100

# %%
#ad = list(frequencies.values())

# %%
#ad = ad.astype('int')

# %%
#int(list(frequencies.values()))/100

# %%
#perc = 50.0 
#min_count =  int(((100-perc)/100)*demographic.shape[1] + 1)
#demographic = demographic.dropna( axis=0, thresh=min_count)

# %%
Finaldata
# Out:
#         primaryid  age age_cod age_grp sex  wt wt_cod  country  cluster  \
# 0       143485691   56      YR     NaN   0  62     KG        2        0
# 4       140961033   27      YR     NaN   0  72     KG        1        1
# 7       113503643   65      YR     NaN   1  77     KG        1        0
# 9       113503643   65      YR     NaN   1  77     KG        1        0
# 11      146567751   78      YR       E   0  68     KG        1        0
# ...           ...  ...     ...     ...  ..  ..    ...      ...      ...
# 364126  143855871   57      YR       A   0  65     KG        1        0
# 364132  143855871   57      YR       A   0  65     KG        1        0
# 364138  143855871   57      YR       A   0  65     KG        1        0
# 364144  143855871   57      YR       A   0  65     KG        1        0
# 364150  143855871   57      YR       A   0  65     KG        1        0
#
#        drugname prod_ai  Death
# 0         33626    3311      0
# 4         32962    2375      0
# ...

# %%
Finaldata.sex.value_counts()
# Out:
# 0    43171
# 1    29558
# Name: sex, dtype: int64

# %%
Finaldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72729 entries, 0 to 364150
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   primaryid  72729 non-null  int64
#  1   age        72729 non-null  int32
#  2   age_cod    72729 non-null  object
#  3   age_grp    13916 non-null  object
#  4   sex        72729 non-null  category
#  5   wt         72729 non-null  int32
#  6   wt_cod     72729 non-null  object
#  7   country    72729 non-null  int64
#  8   cluster    72729 non-null  int32
#  9   drugname   72729 non-null  category
#  10  prod_ai    72729 non-null  category
#  11  Death      72729 non-null  uint8
# dtypes: category(3), int32(3), int64(2), object(3), uint8(1)
# memory usage: 5.0+ MB

# %% [markdown]
# ##FINAL DATASET CORRELATION BY 'SPEARMAN'

# %%
plt.figure(figsize = (20,10))
sns.heatmap(Finaldata.corr(method = 'spearman'), annot = True)
#check method correlation
# Out:
# <AxesSubplot:>

# %%
#IMPORT LIBRARIES FOR IMBALANCING SOLVER

from imblearn.over_sampling import SMOTE
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from imblearn.combine import SMOTEENN

# %%
X = Finaldata[['age','sex','wt','country','cluster','drugname','prod_ai']].values
y = Finaldata.iloc[:, -1].values

# %%
Finaldata.to_csv('finaldata.csv')

# %%
sc = StandardScaler()
X = sc.fit_transform(X)

# %% [markdown]
# #TRAINING DATASET

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
counter = Counter(y_test)
print(counter)
# Out:
# Counter({0: 17889, 1: 294})

# %%
#for label, _ in counter.items():
#	row_ix = where(y == label)[0]
#	pyplot.scatter(X1[row_ix, 0], X1[row_ix, 1], label=str(label))
#pyplot.legend()
#pyplot.show()

# %%
#from sklearn.model_selection import train_test_split
#X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.25, random_state = 0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X1_train = sc.fit_transform(X1_train)
#X1_test = sc.transform(X1_test)

# %%
#print(XS1_train)

# %%
#print(XdecS2_train)

# %%
#X1_train

# %%
#def plot_precision_recall_curve(y_test, y_score, model_name):
    #precision, recall, _ = metrics.precision_recall_curve(y_test, y_score)
    #curve_data = pd.DataFrame(columns = range(0, len(precision)))
    #curve_data.loc['Precision'] = precision
    #curve_data.loc['Recall'] = recall
    #print (curve_data)
    #plt.step(recall, precision, color='b', alpha=0.2, where='post')
    #plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
    #plt.title('Precision Recall Curve for {} Model'.format(model_name))
    #plt.xlabel('Recall')
    #plt.ylabel('Precision')
    #plt.xlim([0, 1.05])
    #plt.ylim([0, 1.0])

# %%
#def evaluate_model(y_test, y_pred, y_score, model_name):
    #cm = metrics.confusion_matrix(y_test, y_pred)
    #print ('Confusion Matrix for {} Model'.format(model_name))
    #print (cm)
    #print ('Classification Report for {} Model'.format(model_name))
    #print (metrics.classification_report(y_test, y_pred, digits=6))
    #print ('Area under under ROC curve for {} Model'.format(model_name))
    #print (metrics.roc_auc_score(y_test, y_score))
    #plot_precision_recall_curve(y_test, y_score, model_name)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ##DATA CROSS VALIDATION AND TRAINING WITH-OUT APPLY IMBALANCING TREATMENT (KFOLD 5)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
classifiers1 = []

classifiers1.append(("LogisticRegression",LogisticRegression())),
classifiers1.append(("KNeighbors",KNeighborsClassifier())),
classifiers1.append(("DecisionTree",DecisionTreeClassifier())),
classifiers1.append(("RandomForest",RandomForestClassifier(n_estimators=100, criterion='gini',max_depth=27, random_state=0, max_features=None))),
classifiers1.append(("XGBOOSTING",XGBClassifier(learning_rates= 0.3, max_depth= 6, child_weight= 1, n_estimators= 150, subsample= 1.0)))
accuracy_means1 = []
names = []
accuracy_results = []
target_names = ['not dead', 'dead']
modeloutcomes = []
modelnames = []
kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
for name,model in classifiers1:
        v_results = cross_val_score(model, X_train, y_train, cv = kfold, 
                                     scoring='accuracy', n_jobs = -1, verbose = 0)
        print(name,v_results.mean())
        modeloutcomes.append(v_results)
        modelnames.append(name)
        accuracy_means1 = []
for e in modeloutcomes:
  accuracy_means1.append(e.mean()*100)
# Out:
# LogisticRegression 0.9859934653137079
# KNeighbors 0.9856268056740374
# DecisionTree 0.97781685317894
# RandomForest 0.9810251762791576
# XGBOOSTING 0.9833168116303199

# %%
#models = []

#def classification_Models(X_train,X_test, y_train, y_test ):
    

    
    #models.append( ('Logistic Regression',  LogisticRegression()) )
    #models.append( ('Decision Tree',DecisionTreeClassifier()) )
    #models.append( ('KNN', KNeighborsClassifier()) )
    #models.append( ("RandomForest",RandomForestClassifier(n_estimators=100, criterion='gini',max_depth=27, random_state=0, max_features=None )))

    #modeloutcomes = []
    #modelnames = []
    #for name,model in models:
        #v_results = cross_val_score(model, X_train, y_train, cv = 5,scoring='accuracy', n_jobs = -1, verbose = 0)
       # print(name,v_results.mean())
        #modeloutcomes.append(v_results)
        #modelnames.append(name)
        #accuracy_means1 = []
    #for e in modeloutcomes:
      #accuracy_means1.append(e.mean()*100)
        
    #print(modeloutcomes)
    #fig = plt.figure(figsize=(10,5))
    #ax = fig.add_subplot(111)
    #ax.set_xticklabels(modelnames)
    ##plt.boxplot(modeloutcomes)
        
#classification_Models(X_train,X_test, y_train, y_test)

# %%
from sklearn.metrics import accuracy_score
for  name,model in classifiers1:
    trainedmodel = model.fit(X_train,y_train)
    
    # prediction
    ypredict = trainedmodel.predict(X_test)
    acc = accuracy_score(y_test,ypredict)
    classreport = classification_report(y_test,ypredict)
    
    
    print('\n****************************'+name)
    print('The accuracy: {}'.format(acc))
    print('The Classification Report:\n {}'.format(classreport))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# Precision is the ratio between the True Positives and all the Positives.
# how many correctly predicting we have made in our Model.
#
# The recall is the measure of our model correctly identifying True Positives

# %%
from xgboost import XGBClassifier
model = XGBClassifier(learning_rates= 0.3, max_depth= 6, child_weight= 1, n_estimators= 150, subsample= 1.0)
model.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:13:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "child_weight", "learning_rates" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ...

# %%
y_xgb = model.predict(X_test)
print(classification_report(y_test,y_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     17889
#            1       0.34      0.06      0.11       294
#
#     accuracy                           0.98     18183
#    macro avg       0.66      0.53      0.55     18183
# weighted avg       0.97      0.98      0.98     18183

# %%
##from sklearn.model_selection import GridSearchCV
#import xgboost as xgb
#param_grid = {
    #'max_depth': [int(x) for x in np.linspace(start = 8, stop = 32)],
    #'learning_rate' : [0.1,0.01,0.05],
    #'gamma' :[0,0.25,1.0],
    #'reg_lambda' : [0,1.0,10.0],
    ##'scale_pos_weight': [1,3,5]
#}
#optimal_params = GridSearchCV(estimator=xgb.XGBClassifier(objective='binary:logistic',
 #                                                          seed= 42,
  #                                                         sub_sample=0.9,
   #                                                        colsample_bytree=0.5),
    #                          param_grid = param_grid,scoring='roc_auc',verbose=0,n_jobs=10,cv=3)

# %%
#optimal_params.fit(X_train,y_train,early_stopping_rounds= 10,
                   #eval_metric='auc',eval_set=[(X_test,y_test)],
                   #verbose=False)

# %%
#print(optimal_params.best_params_)

# %%
#labels = ["Logistic Regression" , "DecisionTreeClassifier","Random Forest","KNN"]
#eval_frame = pd.DataFrame()
#eval_frame['Model'] = labels
#eval_frame['Kfold'] = accuracy_means1
#eval_frame
# Out:
#                     Model      Kfold
# 0     Logistic Regression  98.599347
# 1  DecisionTreeClassifier  98.562681
# 2           Random Forest  97.803686
# 3                     KNN  98.102518

# %% [markdown]
# ##SMOTE TRANING

# %%
#from sklearn.model_selection import train_test_split
#XS1_train, XS1_test, yS1_train, yS1_test = train_test_split(X1, y1, test_size = 0.25, random_state = 42)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#XS1_train = sc.fit_transform(XS1_train)
#XS1_test = sc.transform(XS1_test)

# %%
Counter(y_train)
# Out:
# Counter({0: 53782, 1: 764})

# %%
#SMOTE OVERSAMPLING DATASET 
oversample = SMOTE(random_state= 42)
X1_train, y1_train = oversample.fit_resample(X_train,y_train)

# %% [markdown]
# Grid Search  :Define a search space  as a grid of hyperparameter values and evaluate every position in the grid

# %%
pipe_lr = Pipeline([('LR', LogisticRegression(random_state=42))])
pipe_dt = Pipeline([('DT',DecisionTreeClassifier(random_state=42))])
pipe_rf = Pipeline([('RF',RandomForestClassifier(random_state=42))])
pipe_knn = Pipeline([('KNN', KNeighborsClassifier())])
pipe_xgb = Pipeline([('XGB', XGBClassifier(random_state=42))])

# %%
param_range = [1, 2, 3, 4, 5, 6]
param_range_fl = [1.0, 0.5, 0.1]
n_estimators = [50,100,150]
learning_rates = [.1,.2,.3]
lr_param_grid = [{'LR__penalty': ['l1', 'l2'],
                   'LR__C': param_range_fl,
                   'LR__solver': ['liblinear']}]
dt_param_grid = [{'DT__criterion': ['gini', 'entropy'],
                   'DT__min_samples_leaf': param_range,
                   'DT__max_depth': param_range,
                   'DT__min_samples_split': param_range[1:]}]
rf_param_grid = [{'RF__min_samples_leaf': param_range,
                   'RF__max_depth': param_range,
                   'RF__min_samples_split': param_range[1:]}]
knn_param_grid = [{'KNN__n_neighbors': param_range,
                   'KNN__weights': ['uniform', 'distance'],
                   'KNN__metric': ['euclidean', 'manhattan']}]
svm_param_grid = [{'SVM__kernel': ['linear', 'rbf'], 
                    'SVM__C': param_range}]
xgb_param_grid = [{'XGB__learning_rate': learning_rates,
                    'XGB__max_depth': param_range,
                    'XGB__min_child_weight': param_range[:2],
                    'XGB__subsample': param_range_fl,
                    'XGB__n_estimators': n_estimators}]

# %%
lr_grid_search = GridSearchCV(estimator=pipe_lr,
        param_grid=lr_param_grid,
        scoring='roc_auc',n_jobs=-1,
        cv=5)
dt_grid_search = GridSearchCV(estimator=pipe_dt,
        param_grid=dt_param_grid,
        scoring='roc_auc',n_jobs=-1,
        cv=5)
rf_grid_search = GridSearchCV(estimator=pipe_rf,
        param_grid=rf_param_grid,n_jobs=-1,
        scoring='roc_auc',
        cv=5)
knn_grid_search = GridSearchCV(estimator=pipe_knn,
        param_grid=knn_param_grid,n_jobs=-1,
        scoring='roc_auc',
        cv=5)
xgb_grid_search = GridSearchCV(estimator=pipe_xgb,
        param_grid=xgb_param_grid,n_jobs=-1,
        scoring='roc_auc',
        cv=5)

# %%
#grids = [lr_grid_search, dt_grid_search, rf_grid_search, knn_grid_search, xgb_grid_search]
#for pipe in grids:
   #pipe.fit(X1_train,y1_train)

# %%
#grid_dict = {0: 'Logistic Regression', 1: 'Decision Trees', 
            # 2: 'Random Forest', 3: 'K-Nearest Neighbors', 
            # 4: 'XGBoost'}
#for i, model in enumerate(grids):
 #   print('{} Test Accuracy: {}'.format(grid_dict[i],
  #  model.score(X_test,y_test)))
   # print('{} Best Params: {}'.format(grid_dict[i],          model.best_params_))


#Logistic Regression Test Accuracy: 0.6643799842034191
#Logistic Regression Best Params: {'LR__C': 1.0, 'LR__penalty': 'l2', 'LR__solver': 'liblinear'}
#Decision Trees Test Accuracy: 0.7440908276777088
#Decision Trees Best Params: {'DT__criterion': 'gini', 'DT__max_depth': 6, 'DT__min_samples_leaf': 1, 'DT__min_samples_split': 4}
#Random Forest Test Accuracy: 0.760157022728595
#Random Forest Best Params: {'RF__max_depth': 6, 'RF__min_samples_leaf': 1, 'RF__min_samples_split': 2}
#K-Nearest Neighbors Test Accuracy: 0.6875920025341458
#K-Nearest Neighbors Best Params: {'KNN__metric': 'manhattan', 'KNN__n_neighbors': 6, 'KNN__weights': 'uniform'}
#XGBoost Test Accuracy: 0.8985906286042842
#XGBoost Best Params: {'XGB__learning_rate': 0.3, 'XGB__max_depth': 6, 'XGB__min_child_weight': 1, 'XGB__n_estimators': 150, 'XGB__subsample': 1.0}

# %%
#model.best_params_

# %%
Counter(y1_train)
# Out:
# Counter({0: 53782, 1: 53782})

# %%
for  name,model in classifiers1:
    trainedmodel = model.fit(X1_train,y1_train)

    # prediction
    ypredict1 = trainedmodel.predict(X_test)
    acc = accuracy_score(y_test,ypredict1)
    classreport = classification_report(y_test,ypredict1)


    print('\n**'+name)
    print('The accuracy: {}'.format(acc))
    print('The Classification Report:\n {}'.format(classreport))
#X1_train, y1_train
# Out:
# **LogisticRegression
# The accuracy: 0.640433371830831
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.64      0.78     17889
#            1       0.03      0.57      0.05       294
#
#     accuracy                           0.64     18183
#    macro avg       0.51      0.61      0.41     18183
# weighted avg       0.97      0.64      0.77     18183
#
#
# **KNeighbors
# The accuracy: 0.8863223890447121
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     17889
#            1       0.05      0.32      0.08       294
#
#     accuracy                           0.89     18183
#    macro avg       0.52      0.61      0.51     18183
# weighted avg       0.97      0.89      0.93     18183
#
#
# **DecisionTree
# The accuracy: 0.9649672771269867
# The Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ##SMOTEENN TRAINING
#
# 1.   Mục danh sách
# 2.   Mục danh sách

# %%
from imblearn.combine import SMOTEENN
smote2 = SMOTEENN()

# %%
X2_train,y2_train = smote2.fit_resample(X_train,y_train)

# %%
for  name,model in classifiers1:
    trainedmodel = model.fit(X2_train,y2_train)

    # prediction
    ypredict1 = trainedmodel.predict(X_test)
    acc = accuracy_score(y_test,ypredict1)
    classreport = classification_report(y_test,ypredict1)


    print('\n**'+name)
    print('The accuracy: {}'.format(acc))
    print('The Classification Report:\n {}'.format(classreport))
# Out:
# **LogisticRegression
# The accuracy: 0.5963812352197108
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.60      0.74     17889
#            1       0.02      0.61      0.05       294
#
#     accuracy                           0.60     18183
#    macro avg       0.51      0.60      0.40     18183
# weighted avg       0.97      0.60      0.73     18183
#
#
# **KNeighbors
# The accuracy: 0.8581092229005115
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.87      0.92     17889
#            1       0.05      0.40      0.08       294
#
#     accuracy                           0.86     18183
#    macro avg       0.52      0.63      0.50     18183
# weighted avg       0.97      0.86      0.91     18183
#
#
# **DecisionTree
# The accuracy: 0.9427487213331134
# The Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# #EVALUATING MODELS BY ROC,AUC CURVES

# %%
#from sklearn.metrics import roc_curve, auc
#false_positive_rate, true_positive_rate, thresholds = roc_curve(y1f_test, yforest_pred)
#roc_auc = auc(false_positive_rate, true_positive_rate)
#roc_auc

# %%
#max_depths = np.linspace(1, 50,50,  endpoint=True)
#train_results = []
#test_results = []
#for max_depth in max_depths:
   #rf = RandomForestClassifier(max_depth=max_depth, n_jobs=-1)
   #rf.fit(X1f_train, y1f_train)
   #train_pred = rf.predict(X1f_train)
   #false_positive_rate, true_positive_rate, thresholds = roc_curve(y1f_train, train_pred)
   #roc_auc = auc(false_positive_rate, true_positive_rate)
   #train_results.append(roc_auc)
   #y_pred = rf.predict(X1f_test)
   #false_positive_rate, true_positive_rate, thresholds = roc_curve(y1f_test, yforest_pred)
   #roc_auc = auc(false_positive_rate, true_positive_rate)
   #est_results.append(roc_auc)

# %%
#from matplotlib.legend_handler import HandlerLine2D
#line1, = plt.plot(max_depths, train_results, 'b', label="Train AUC")
#line2, = plt.plot(max_depths, test_results, 'r', label="Test AUC")
#plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
#plt.ylabel("AUC score")
#plt.xlabel("‘Tree depth’")
#plt.show()

# %%
#pip install -U scikit-learn

# %%
#import sklearn
#sklearn.__version__

# %%
#false_positive_rate, true_positive_rate, thresholds = roc_curve(y2f2_test,yforest_pred)
#roc_auc1 = auc(false_positive_rate, true_positive_rate)
#roc_auc1

# %% [markdown]
# ![1_ohzyiAfz6MLqNHLPForN_A.png](data:image/png;base64,...)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
w = np.linspace(0.0,0.99,100)
hyperparam_grid = {"class_weight": w }

# %%
# define model
lg3 = LogisticRegression(random_state=13)
# define evaluation procedure
grid = GridSearchCV(lg3,hyperparam_grid,scoring="roc_auc", cv=100,verbose= 4, n_jobs=-1, refit=True)
grid.fit(X_train,y_train)
print(f'Best score: {grid.best_score_} with param: {grid.best_params_}')
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
# Best score: 0.6784993033448349 with param: {'class_weight': 0.0}

# %%
#XGB__learning_rate': 0.3, 'XGB__max_depth': 6, 'XGB__min_child_weight': 1, 'XGB__n_estimators': 150, 'XGB__subsample': 1.0

# %%
solver_list = ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']
params = dict(solver=solver_list)
log_reg = LogisticRegression(C=1, n_jobs=-1, random_state=42)
clf = GridSearchCV(log_reg, params, cv=5,scoring='roc_auc')
#clf.fit(X_train, y_train)
#scores = clf.cv_results_['mean_test_score']

#for score, solver in zip(scores, solver_list):
    #print(f"  {solver} {score:.3f}" )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1523: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1523: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1523: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1523: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
# Instantiate the classfiers and make a list
w = {0: 1.0, 1: 200}

classifiers = [LogisticRegression(random_state=42,class_weight='balanced'), 
               DecisionTreeClassifier(random_state=42),
               RandomForestClassifier(random_state=42),
               KNeighborsClassifier(n_neighbors=5),
               XGBClassifier(learning_rate=0.3,max_depth=6,min_child_weight=1,subsample=1.0)
               ]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    model = cls.fit(X_train, y_train)
    yproba = model.predict_proba(X_test)[::,1]
    
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
fig = plt.figure(figsize=(15,10))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()

# %%
# Instantiate the classfiers and make a list
classifiers2 = [LogisticRegression(random_state=42,class_weight='balanced'), 
               DecisionTreeClassifier(random_state=42),
               RandomForestClassifier(random_state=42,n_estimators=100),
                KNeighborsClassifier(n_neighbors=5),
                XGBClassifier(learning_rate=0.3,max_depth=6,min_child_weight=1,subsample=1.0)]

# Define a result table as a DataFrame
result_table2 = pd.DataFrame(columns=['classifiers', 'fpr2','tpr2','auc2'])

# Train the models and record the results
for cls in classifiers2:
    model2 = cls.fit(X1_train, y1_train)
    yproba2 = model2.predict_proba(X_test)[::,1]
    
    fpr2, tpr2, _ = roc_curve(y_test,  yproba2)
    auc2 = roc_auc_score(y_test, yproba2)
    
    result_table2 = result_table2.append({'classifiers2':cls.__class__.__name__,
                                        'fpr2':fpr2, 
                                        'tpr2':tpr2, 
                                        'auc2':auc2}, ignore_index=True)

# Set name of the classifiers as index labels
result_table2.set_index('classifiers2', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
fig = plt.figure(figsize=(15,10))

for i in result_table2.index:
    plt.plot(result_table2.loc[i]['fpr2'], 
             result_table2.loc[i]['tpr2'], 
             label="{}, AUC={:.3f}".format(i, result_table2.loc[i]['auc2']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve with SMOTE', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()

# %% [markdown]
# ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes. Higher the AUC, the better the model is at predicting 0 classes as 0 and 1 classes as 1.
#
# AUC score is equal to the probability that a classifier will rank a randomly chosen positive instance higher than a randomly chosen negative one.
#
# The area under the ROC curve (AUC) results were considered excellent for AUC values between 0.9-1, good for AUC values between 0.8-0.9, fair for AUC values between 0.7-0.8, poor for AUC values between 0.6-0.7 and failed for AUC values between 0.5-0.6.

# %%
# Instantiate the classfiers and make a list

# Define a result table as a DataFrame
result_table3 = pd.DataFrame(columns=['classifiers', 'fpr3','tpr3','auc3'])

# Train the models and record the results
for cls in classifiers:
    model3 = cls.fit(X2_train,y2_train)
    yproba3 = model3.predict_proba(X_test)[::,1]
    
    fpr3, tpr3, _ = roc_curve(y_test,  yproba3)
    auc3 = roc_auc_score(y_test, yproba3)
    
    result_table3 = result_table3.append({'classifiers3':cls.__class__.__name__,
                                        'fpr3':fpr3, 
                                        'tpr3':tpr3, 
                                        'auc3':auc3}, ignore_index=True)

# Set name of the classifiers as index labels
result_table3.set_index('classifiers3', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:53:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
fig = plt.figure(figsize=(15,10))

for i in result_table3.index:
    plt.plot(result_table3.loc[i]['fpr3'], 
             result_table3.loc[i]['tpr3'], 
             label="{}, AUC={:.3f}".format(i, result_table3.loc[i]['auc3']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve SMOTE-ENN', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()

# %%
plt.subplot(1, 2, 2)
for i in result_table3.index:
    plt.plot(result_table3.loc[i]['fpr3'], 
             result_table3.loc[i]['tpr3'], 
             label="{}, AUC={:.3f}".format(i, result_table3.loc[i]['auc3']))
    plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis after Balanced', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')


plt.subplot(1, 2, 1)
for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)
plt.title('ROC Curve Analysis before Balanced', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')




plt.title('ROC before using oversampling', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')



plt.suptitle("ROC Curve Analysis", fontweight='bold', fontsize=30)
plt.show()

# %% [markdown]
# **ROC & AUC seem to be reliable than accuraccy. So that why I believe Exmtremely Gradient boost with 5 K-FOLD is the best model to predict Dead event for dataset 2018 of FDA**
